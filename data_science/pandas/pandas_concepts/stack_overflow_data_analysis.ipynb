# %%
import pandas as pd

# %%
df = pd.read_csv("/content/survey_results_public.csv", index_col='Respondent')
schema_df = pd.read_csv("/content/survey_results_schema.csv", index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
schema_df.head()
# Out:
#                                                   QuestionText
# Column
# Respondent   Randomized respondent ID number (not in order ...
# MainBranch   Which of the following options best describes ...
# Hobbyist                               Do you code as a hobby?
# OpenSourcer        How often do you contribute to open source?
# OpenSource   How do you feel about the quality of open sour...

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df['ConvertedComp'].value_counts()
# Out:
# ConvertedComp
# 2000000.0    709
# 1000000.0    558
# 120000.0     502
# 100000.0     480
# 150000.0     434
#             ...
# 411096.0       1
# 261228.0       1
# 82322.0        1
# 66424.0        1
# 588012.0       1
# Name: count, Length: 9162, dtype: int64

# %%
df['ConvertedComp'].median()
# Out:
# 57287.0

# %%
df.describe()
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
df['SocialMedia']
# Out:
# Respondent
# 1          Twitter
# 2        Instagram
# 3           Reddit
# 4           Reddit
# 5         Facebook
#            ...
# 88377      YouTube
# 88601          NaN
# 88802          NaN
# 88816          NaN
# 88863     WhatsApp
# Name: SocialMedia, Length: 88883, dtype: object

# %%
df['SocialMedia'].value_counts()
# Out:
# SocialMedia
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: count, dtype: int64

# %%
type(df['SocialMedia'].value_counts())
# Out:
# pandas.core.series.Series

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df['Country'].value_counts(normalize=True)
# Out:
# Country
# United States        0.236042
# India                0.102095
# Germany              0.066095
# United Kingdom       0.064642
# Canada               0.038253
#                        ...
# Tonga                0.000011
# Timor-Leste          0.000011
# North Korea          0.000011
# Brunei Darussalam    0.000011
# Chad                 0.000011
# Name: proportion, Length: 179, dtype: float64

# %%
country_grp = df.groupby('Country')
country_grp

# %%
country_grp.get_group('India')
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# ...

# %%
filt = (df['Country'] == 'India')
df[filt]['SocialMedia'].value_counts()
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: count, dtype: int64

# %%
country_grp['SocialMedia'].value_counts(normalize=True)['China']
# Out:
# SocialMedia
# WeChat 微信                   0.670549
# YouTube                     0.088186
# Weibo 新浪微博                  0.069884
# I don't use social media    0.044925
# Twitter                     0.044925
# Reddit                      0.019967
# LinkedIn                    0.018303
# Facebook                    0.013311
# Instagram                   0.011647
# Youku Tudou 优酷              0.011647
# WhatsApp                    0.004992
# VK ВКонта́кте               0.001664
# Name: proportion, dtype: float64

# %%
df['SocialMedia'].mode()
# Out:
# 0    Reddit
# Name: SocialMedia, dtype: object

# %%
country_grp['ConvertedComp'].median().loc['India']
# Out:
# 10080.0

# %%
country_grp['ConvertedComp'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %%
## one not so good way
filt = (df['LanguageWorkedWith'].str.contains('Python'))
filt.fillna(False, inplace=True)
df.loc[filt]['LanguageWorkedWith']
# Out:
# <ipython-input-95-3af978c302ae>:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   filt.fillna(False, inplace=True)
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# ...

# %%
## good way
filt = (df['Country'] == 'India')
df[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %%
## this will give an error
# country_grp['LanguageWorkedWith'].str.contains('Python')

# %% [markdown]
# Below are the 2 different ways sum()  is used with an apply() function

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %% [markdown]
# What % of people from each country know Python?

# %%
# my solutio doesnt exactly do what the question asks to be done
ct = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
(ct / ct.sum()).sort_values(ascending=False)
# Out:
# Country
# United States     0.276679
# India             0.085202
# Germany           0.067256
# United Kingdom    0.065417
# Canada            0.042752
#                     ...
# Malawi            0.000000
# Tonga             0.000000
# Djibouti          0.000000
# Liberia           0.000000
# Cape Verde        0.000000
# Name: LanguageWorkedWith, Length: 179, dtype: float64

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum()).loc['India']
# Out:
# 3105

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python'))
# Out:
# Country      Respondent
# Afghanistan  722             NaN
#              6417          False
#              7085          False
#              7353          False
#              8149          False
#                            ...
# Zimbabwe     76594         False
#              77533         False
#              82752         False
#              83850         False
#              84155         False
# Name: LanguageWorkedWith, Length: 88751, dtype: object

# %% [markdown]
# Practice

# %%
population = pd.Series(data=[100, 200, 300, 400, 500, 234], index=['India', 'Japan', 'China', 'United States', 'Nepal', 'Australia'], name='Population')
population
# Out:
# India            100
# Japan            200
# China            300
# United States    400
# Nepal            500
# Australia        234
# Name: Population, dtype: int64

# %%
knows_python = pd.Series(data=[10, 50, 172, 38, 112, 234], index=[ 'United States', 'Nepal', 'China', 'India', 'Japan', 'North Korea'], name='knowsPython')
knows_python
# Out:
# United States     10
# Nepal             50
# China            172
# India             38
# Japan            112
# North Korea      234
# Name: knowsPython, dtype: int64

# %%
python_df = pd.concat([population, knows_python], axis='columns', join='inner')
python_df
# Out:
#                Population  knowsPython
# India                 100           38
# Japan                 200          112
# China                 300          172
# United States         400           10
# Nepal                 500           50

# %%
python_df['per_knows_python'] = (python_df['knowsPython']/python_df['Population']) * 100
python_df
# Out:
#                Population  knowsPython  per_knows_python
# India                 100           38         38.000000
# Japan                 200          112         56.000000
# China                 300          172         57.333333
# United States         400           10          2.500000
# Nepal                 500           50         10.000000

# %% [markdown]
# - doing the same as above for our original df

# %%
# the right solution and the right way
num_people_each_country = country_grp['Res']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-106-9d0c275bad71> in <cell line: 2>()
#       1 # the right solution and the right way
# ----> 2 num_people_each_country = country_grp['Res']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1949                 "Use a list instead."
#    1950             )
# -> 1951         return super().__getitem__(key)
#    1952
#    1953     def _gotitem(self, key, ndim: int, subset=None):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in __getitem__(self, key)
#     242         else:
#     243             if key not in self.obj:
# --> 244                 raise KeyError(f"Column not found: {key}")
#     245             ndim = self.obj[key].ndim
#     246             return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: Res'

# %%
s = pd.Series([1, 23, 343, 4, 5])

# %%
pd.concat([knows_python, s], axis=1)

# %%
import pandas as pd
import numpy as np

# Example DataFrame
data = {
    'A': [1, np.nan, 3],
    'B': [4, np.nan, np.nan],
    'C': [7, 8, np.nan]
}
df = pd.DataFrame(data,)
print("Original DataFrame:")
print(df)

# %%
df.fillna(0, axis=0)

# %%
# Filling NaN with a column-specific value
filled_axis_0 = df.fillna({'A': 10, 'B': 20, 'C': 30})
print("\nFilled DataFrame with axis=0 (column-wise):")
print(filled_axis_0)

# %%
# Proof for axis=0
print("\nProof for axis=0 (column-wise):")
print(df.fillna({'A': 10, 'B': 20, 'C': 30}))

# %%
filled_row_ffill = df.fillna(method='ffill')
filled_row_ffill

# %%
filled_row_ffill = df.fillna(method='ffill', axis=1)

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# Country
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: count, Length: 179, dtype: int64

# %%
num_people_know_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
num_people_know_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_df = pd.concat([country_respondents, num_people_know_python], axis='columns')
python_df
# Out:
#                    count  LanguageWorkedWith
# Country
# United States      20949               10083
# India               9061                3105
# Germany             5866                2451
# United Kingdom      5737                2384
# Canada              3395                1558
# ...                  ...                 ...
# Tonga                  1                   0
# Timor-Leste            1                   1
# North Korea            1                   0
# Brunei Darussalam      1                   0
# Chad                   1                   0
#
# [179 rows x 2 columns]

# %%
python_df.rename(columns={'count': 'total_people', 'LanguageWorkedWith': 'num_know_python'}, inplace=True)

# %%
python_df
# Out:
#                    total_people  num_know_python
# Country
# United States             20949            10083
# India                      9061             3105
# Germany                    5866             2451
# United Kingdom             5737             2384
# Canada                     3395             1558
# ...                         ...              ...
# Tonga                         1                0
# Timor-Leste                   1                1
# North Korea                   1                0
# Brunei Darussalam             1                0
# Chad                          1                0
#
# [179 rows x 2 columns]

# %%
python_df['per_know_python'] = (python_df['num_know_python'] / python_df['total_people']) * 100
python_df
# Out:
#                    total_people  num_know_python  per_know_python
# Country
# United States             20949            10083        48.131176
# India                      9061             3105        34.267741
# Germany                    5866             2451        41.783157
# United Kingdom             5737             2384        41.554820
# Canada                     3395             1558        45.891016
# ...                         ...              ...              ...
# Tonga                         1                0         0.000000
# Timor-Leste                   1                1       100.000000
# North Korea                   1                0         0.000000
# Brunei Darussalam             1                0         0.000000
# Chad                          1                0         0.000000
#
# [179 rows x 3 columns]

# %%
python_df.sort_values(by='per_know_python', ascending=False, inplace=True)

# %%
python_df.head(15)
# Out:
#                            total_people  num_know_python  per_know_python
# Country
# Sao Tome and Principe                 1                1       100.000000
# Timor-Leste                           1                1       100.000000
# Dominica                              1                1       100.000000
# Niger                                 1                1       100.000000
# Turkmenistan                          7                6        85.714286
# Mauritania                            7                5        71.428571
# Guinea                                3                2        66.666667
# Bahamas                               3                2        66.666667
# Guyana                                3                2        66.666667
# Uganda                               72               47        65.277778
# Iceland                              49               30        61.224490
# Haiti                                 5                3        60.000000
# ...

# %%
python_df.loc['Japan']
# Out:
# total_people       391.000000
# num_know_python    182.000000
# per_know_python     46.547315
# Name: Japan, dtype: float64
