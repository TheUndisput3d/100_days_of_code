# %%
import pandas as pd
import numpy as np
df = pd.read_csv("../datasets/Churn.csv")

# %%
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %% [markdown]
# Ex: Get 5 customeres who made the lowest number of total day calls.

# %%
df.sort_values(by="total day calls")
# Out:
#      state  account length  area code phone number international plan  \
# 1397    VT             101        510     413-7655                 no
# 1345    SD              98        415     392-2555                 no
# 1144    NH             155        408     353-6300                 no
# 1989    MT             124        415     420-5652                 no
# 692     NE              82        408     343-2741                 no
# ...    ...             ...        ...          ...                ...
# 315     MA              39        408     332-2462                 no
# 1057    WV              86        415     332-2258                 no
# 1460    MT              80        415     361-8288                 no
# 468     AZ              86        415     392-2381                 no
# 1121    MI              91        415     390-7930                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
df.sort_values(by="total day calls", ascending=False)
# Out:
#      state  account length  area code phone number international plan  \
# 1121    MI              91        415     390-7930                 no
# 468     AZ              86        415     392-2381                 no
# 1460    MT              80        415     361-8288                 no
# 2392    WY              90        510     400-8069                 no
# 1057    WV              86        415     332-2258                 no
# ...    ...             ...        ...          ...                ...
# 692     NE              82        408     343-2741                 no
# 1989    MT             124        415     420-5652                 no
# 1144    NH             155        408     353-6300                 no
# 1397    VT             101        510     413-7655                 no
# 1345    SD              98        415     392-2555                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %% [markdown]
# ###sort by multple columns

# %% [markdown]
# Ex: sort the customers who made the highesst number of total day calls by state

# %%
df.sort_values(by=["state", "total day calls"], ascending=False).loc[:, ['state', 'total day calls',]]
# Out:
#      state  total day calls
# 2392    WY              158
# 238     WY              148
# 1018    WY              148
# 1751    WY              142
# 49      WY              135
# ...    ...              ...
# 1024    AK               65
# 2571    AK               62
# 1884    AK               60
# 550     AK               58
# 1589    AK               55
#
# [3333 rows x 2 columns]

# %% [markdown]
# sort one column by ascending and the other column by descending order.

# %% [markdown]
# Ex: Sorting state column by ascending and total day calls in descending order

# %%
df.sort_values(by=["state", "total day calls"], ascending=[True, False]).loc[:, ['state', 'total day calls',]]
# Out:
#      state  total day calls
# 950     AK              129
# 36      AK              128
# 3088    AK              127
# 718     AK              124
# 2071    AK              121
# ...    ...              ...
# 2819    WY               68
# 3172    WY               67
# 653     WY               65
# 609     WY               55
# 1422    WY               45
#
# [3333 rows x 2 columns]

# %% [markdown]
# ## Map and Applymap

# %%
df = pd.read_csv("../datasets/Tips100.csv")
df.head()
# Out:
#    total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0       18.69  2.31    Male     No   Sat  Dinner     3              6.23
# 1       17.29  2.71    Male     No  Thur   Lunch     2              8.64
# 2       11.87  1.63  Female     No  Thur   Lunch     2              5.94
# 3       10.65  1.50  Female     No  Thur   Lunch     2              5.32
# 4        9.78  1.73    Male     No  Thur   Lunch     2              4.89
#
#            Payer Name         CC Number Payment ID
# 0     Brandon Bradley  4427601595688633    Sat4056
# 1          Brian Diaz  4759290988169738   Thur9501
# 2  Annette Cunningham      675937746864   Thur4780
# 3         Linda Zhang  3560509622598239   Thur9593
# 4       David Stewart  3578014604116399   Thur7276

# %% [markdown]
# assign()

# %%
def tip_perc(df):
  print(df.head(2))
  return round(df['tip'] /df['size'], 2)

# %%
#Way-1
df.assign(tip_per_person = tip_perc, tip_percentage = round(df['tip']/df['total_bill'], 2))
# Out:
#    total_bill   tip   sex smoker   day    time  size  price_per_person  \
# 0       18.69  2.31  Male     No   Sat  Dinner     3              6.23
# 1       17.29  2.71  Male     No  Thur   Lunch     2              8.64
#
#         Payer Name         CC Number Payment ID
# 0  Brandon Bradley  4427601595688633    Sat4056
# 1       Brian Diaz  4759290988169738   Thur9501
#     total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0        18.69  2.31    Male     No   Sat  Dinner     3              6.23
# 1        17.29  2.71    Male     No  Thur   Lunch     2              8.64
# 2        11.87  1.63  Female     No  Thur   Lunch     2              5.94
# 3        10.65  1.50  Female     No  Thur   Lunch     2              5.32
# 4         9.78  1.73    Male     No  Thur   Lunch     2              4.89
# ..         ...   ...     ...    ...   ...     ...   ...               ...
# 95       26.41  1.50  Female     No   Sat  Dinner     2             13.20
# ...

# %%
#Way-2
df.assign(tip_per_person = lambda df: tip_perc(df), tip_percentage = round(df['tip']/df['total_bill'], 2))
# Out:
#    total_bill   tip   sex smoker   day    time  size  price_per_person  \
# 0       18.69  2.31  Male     No   Sat  Dinner     3              6.23
# 1       17.29  2.71  Male     No  Thur   Lunch     2              8.64
#
#         Payer Name         CC Number Payment ID
# 0  Brandon Bradley  4427601595688633    Sat4056
# 1       Brian Diaz  4759290988169738   Thur9501
#     total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0        18.69  2.31    Male     No   Sat  Dinner     3              6.23
# 1        17.29  2.71    Male     No  Thur   Lunch     2              8.64
# 2        11.87  1.63  Female     No  Thur   Lunch     2              5.94
# 3        10.65  1.50  Female     No  Thur   Lunch     2              5.32
# 4         9.78  1.73    Male     No  Thur   Lunch     2              4.89
# ..         ...   ...     ...    ...   ...     ...   ...               ...
# 95       26.41  1.50  Female     No   Sat  Dinner     2             13.20
# ...

# %%
#Way-3
df = df.assign(tip_per_person = lambda df: round(df['tip'] /df['size'], 2), tip_percentage = round(df['tip']/df['total_bill'], 2))

# %%
df
# Out:
#     total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0        18.69  2.31    Male     No   Sat  Dinner     3              6.23
# 1        17.29  2.71    Male     No  Thur   Lunch     2              8.64
# 2        11.87  1.63  Female     No  Thur   Lunch     2              5.94
# 3        10.65  1.50  Female     No  Thur   Lunch     2              5.32
# 4         9.78  1.73    Male     No  Thur   Lunch     2              4.89
# ..         ...   ...     ...    ...   ...     ...   ...               ...
# 95       26.41  1.50  Female     No   Sat  Dinner     2             13.20
# 96       17.26  2.74    Male     No   Sun  Dinner     3              5.75
# 97       13.16  2.75  Female     No  Thur   Lunch     2              6.58
# 98       21.16  3.00    Male     No  Thur   Lunch     2             10.58
# 99       15.01  2.09    Male    Yes   Sat  Dinner     2              7.50
#
#             Payer Name         CC Number Payment ID  tip_per_person  \
# ...

# %%
#simple use-case of kwargs, and passing funcs as parameters
def sum(**kwargs):
  sum = 0
  for key, val in kwargs.items():
    sum += val
  return sum

def mean(func, **kwargs):
  print(func(**kwargs) / len(kwargs))

mean(sum, **{'val1': 1, 'val2': 2, 'v': 3})
# Out:
# 2.0

# %%
df['CC Number'].map(lambda x: "x" + str(x)[-4:] if len(str(x))==16 else 'xxxx')
# Out:
# 0     x8633
# 1     x9738
# 2      xxxx
# 3     x8239
# 4     x6399
#       ...
# 95    x8160
# 96     xxxx
# 97     xxxx
# 98    x0422
# 99    x7571
# Name: CC Number, Length: 100, dtype: object

# %%
df['CC Number'].apply(lambda x: str(x)[:4]+str(x)[4:].replace(str(x)[4:], 'x'*16 ))
# Out:
# 0     4427xxxxxxxxxxxxxxxx
# 1     4759xxxxxxxxxxxxxxxx
# 2     6759xxxxxxxxxxxxxxxx
# 3     3560xxxxxxxxxxxxxxxx
# 4     3578xxxxxxxxxxxxxxxx
#               ...
# 95    4745xxxxxxxxxxxxxxxx
# 96    4292xxxxxxxxxxxxxxxx
# 97    6762xxxxxxxxxxxxxxxx
# 98    4356xxxxxxxxxxxxxxxx
# 99    4700xxxxxxxxxxxxxxxx
# Name: CC Number, Length: 100, dtype: object

# %%
'aayush'.replace('aayush', 'pathak')
# Out:
# 'pathak'

# %%
type(np.nan)
# Out:
# float

# %%
'a'*5
# Out:
# 'aaaaa'

# %%
dff = pd.DataFrame(np.random.randint(10, size=(4, 4)), columns=list('abcd'))
dff
# Out:
#    a  b  c  d
# 0  6  3  9  5
# 1  3  9  9  8
# 2  8  0  1  2
# 3  9  2  5  0

# %%
dff.map(lambda x: x+5)
# Out:
#     a   b   c   d
# 0  11   8  14  10
# 1   8  14  14  13
# 2  13   5   6   7
# 3  14   7  10   5

# %%
ser = dff['c']
ser
# Out:
# 0    9
# 1    9
# 2    1
# 3    5
# Name: c, dtype: int32

# %%
ser.map(pd.Series([1, 3, 4, 5]))
# Out:
# 0    NaN
# 1    NaN
# 2    3.0
# 3    NaN
# Name: c, dtype: float64

# %% [markdown]
# * sorting using sorted()
# * sorting by providing two keys

# %%
Age = [('index1', 20, 'A'), ('index100', 24, 'A'),('index1', 50, 'A'),('index2', 40, 'A'),('index2', 19, 'A'),]
sorted(Age, key=lambda x: (int(x[0][5:]), -x[1]))
# Out:
# [('index1', 50, 'A'),
#  ('index1', 20, 'A'),
#  ('index2', 40, 'A'),
#  ('index2', 19, 'A'),
#  ('index100', 24, 'A')]

# %%
people = [
    {"name": "Alice", "age": 30},
    {"name": "David", "age": 25},
    {"name": "Charlie", "age": 30},
    {"name": "Bob", "age": 25},
    {"name": "Grace", "age": 35},
    {"name": "Ivy", "age": 22},
    {"name": "Kathy", "age": 22},
    {"name": "Frank", "age": 28},
    {"name": "Hannah", "age": 22},
    {"name": "Jack", "age": 30},
    {"name": "Eve", "age": 28},
    {"name": "Leo", "age": 40}
]

# %%
sorted(people, key=lambda x: (x['age'], x['name']) )
# Out:
# [{'name': 'Hannah', 'age': 22},
#  {'name': 'Ivy', 'age': 22},
#  {'name': 'Kathy', 'age': 22},
#  {'name': 'Bob', 'age': 25},
#  {'name': 'David', 'age': 25},
#  {'name': 'Eve', 'age': 28},
#  {'name': 'Frank', 'age': 28},
#  {'name': 'Alice', 'age': 30},
#  {'name': 'Charlie', 'age': 30},
#  {'name': 'Jack', 'age': 30},
#  {'name': 'Grace', 'age': 35},
#  {'name': 'Leo', 'age': 40}]

# %%
nested_categories = [
    ["Alice", "Bob", "Charlie", "David"],     # People
    ["Apple", "Banana", "Cherry", "Date"],    # Fruits
    ["Cat", "Dog", "Elephant", "Fox"],        # Animals
    ["Rose", "Tulip", "Sunflower", "Cactus"]  # Plants
]

# %%
for i in range(len(nested_categories)):
    print(nested_categories[i])
# Out:
# ['Alice', 'Bob', 'Charlie', 'David']
# ['Apple', 'Banana', 'Cherry', 'Date']
# ['Cat', 'Dog', 'Elephant', 'Fox']
# ['Rose', 'Tulip', 'Sunflower', 'Cactus']

# %%
[sorted(lst, key=len) for lst in nested_categories]
# Out:
# [['Alice', 'Bob', 'Charlie', 'David'],
#  ['Apple', 'Banana', 'Cherry', 'Date'],
#  ['Cat', 'Dog', 'Elephant', 'Fox'],
#  ['Cactus', 'Rose', 'Sunflower', 'Tulip']]

# %%
[sorted(lst, key=lambda x : x[0]) for lst in nested_categories]
# Out:
# [['Alice', 'Bob', 'Charlie', 'David'],
#  ['Apple', 'Banana', 'Cherry', 'Date'],
#  ['Cat', 'Dog', 'Elephant', 'Fox'],
#  ['Cactus', 'Rose', 'Sunflower', 'Tulip']]

# %%
lsts = []
for i in nested_categories:
    (lsts.append(sorted(i, key=lambda x : x[0])))

# %%
print(lsts)
# Out:
# [['Alice', 'Bob', 'Charlie', 'David'], ['Apple', 'Banana', 'Cherry', 'Date'], ['Cat', 'Dog', 'Elephant', 'Fox'], ['Cactus', 'Rose', 'Sunflower', 'Tulip']]

# %%
ind_val = ['index'+str(val) for val in range(1, 6)]

# %%
indexed_values = [
    "index1", "index2", "index3", "index4", "index5"
]
list(map(lambda x: int(x[5:])**2, indexed_values))
# Out:
# [1, 4, 9, 16, 25]

# %%
lst = list(map(lambda x: x**2, list(map(lambda x: int(x[5:]), indexed_values))))

# %%
lst2 = list(filter(lambda x: x<10, lst))
lst2
# Out:
# [1, 4, 9]

# %%
import functools as f
f.reduce(lambda a, b: a+b, lst2)/len(lst2)
# Out:
# 4.666666666666667

# %%
l = [2, 3, 4, 5]
def add_all(a, b):
    print(a, b)
    return a+b
f.reduce(add_all, l)
# Out:
# 2 3
# 5 4
# 9 5
# 14
