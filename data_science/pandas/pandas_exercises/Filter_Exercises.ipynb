# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1. Write a Pandas program to display the dimensions or shape of the World alcohol consumption dataset. Also extract the column names from the dataset.

# %%
df1 = pd.read_csv('/content/world_alcohol.csv')
df1.head()
print(df1.shape)
df1.ndim
# Out:
# (100, 5)
# 2

# %% [markdown]
# 2. Write a Pandas program to select first 2 rows, 2 columns and specific two columns from World alcohol consumption dataset.

# %%
#first_rows
print(df1.loc[:1, :])

#first 2 cols:
df1.loc[:, :'WHO region']
# Out:
#    Year       WHO region   Country Beverage Types  Display Value
# 0  1986  Western Pacific  Viet Nam           Wine            0.0
# 1  1986         Americas   Uruguay          Other            0.5
#     Year       WHO region
# 0   1986  Western Pacific
# 1   1986         Americas
# 2   1985           Africa
# 3   1986         Americas
# 4   1987         Americas
# ..   ...              ...
# 95  1984           Africa
# 96  1985           Europe
# 97  1984  South-East Asia
# 98  1984           Africa
# 99  1985  South-East Asia
#
# [100 rows x 2 columns]

# %% [markdown]
# 3.Program to select a random number of rows, fraction of random rows

# %%
df1.sample(5)
# Out:
#     Year             WHO region             Country Beverage Types  \
# 17  1989                 Africa          Seychelles           Beer
# 34  1986                 Europe  Russian Federation           Wine
# 14  1985        Western Pacific            Viet Nam        Spirits
# 93  1987                 Africa          Madagascar          Other
# 87  1989  Eastern Mediterranean                Iraq           Wine
#
#     Display Value
# 17           2.23
# 34           0.80
# 14           0.05
# 93            NaN
# 87           0.01

# %%
#fraction of rows
df1.sample(frac=0.2)
# Out:
#     Year             WHO region  \
# 99  1985        South-East Asia
# 26  1985                 Europe
# 28  1987        Western Pacific
# 45  1989                 Africa
# 58  1984  Eastern Mediterranean
# 25  1984  Eastern Mediterranean
# 16  1984               Americas
# 90  1989                 Africa
# 42  1984                 Europe
# 47  1986               Americas
# 15  1987                 Africa
# 52  1986  Eastern Mediterranean
# 88  1987  Eastern Mediterranean
# 96  1985                 Europe
# 57  1989                 Europe
# 70  1986                 Africa
# 60  1987  Eastern Mediterranean
# 2   1985                 Africa
# 13  1984  Eastern Mediterranean
# 91  1989                 Europe
#
#                                               Country Beverage Types  \
# 99              Democratic People's Republic of Korea           Wine
# 26  United Kingdom of Great Britain and Northern I...           Wine
# 28                                           Viet Nam           Beer
# 45                                           Zimbabwe           Beer
# 58                                            Somalia        Spirits
# 25                                            Tunisia          Other
# 16                                         Costa Rica           Wine
# 90                                             Malawi           Wine
# 42                                            Ukraine        Spirits
# 47                                             Mexico          Other
# 15                                      Guinea-Bissau           Wine
# 52                                       Saudi Arabia           Wine
# 88                                            Lebanon           Beer
# 96                                         Luxembourg           Wine
# 57                                            Croatia           Wine
# 70                                         Madagascar        Spirits
# 60                         Iran (Islamic Republic of)          Other
# 2                                        Cte d'Ivoire           Wine
# 13                                        Afghanistan          Other
# 91                                           Bulgaria           Beer
#
#     Display Value
# 99           0.00
# 26           1.36
# 28           0.11
# 45           0.19
# 58           0.00
# 25           0.00
# 16           0.06
# 90           0.01
# 42           3.06
# 47           0.04
# 15           0.07
# 52           0.00
# 88           0.42
# 96           7.38
# 57           5.10
# 70           1.02
# 60           0.00
# 2            1.62
# 13           0.00
# 91           4.43

# %% [markdown]
# Write a Pandas program to find and drop the missing values from World alcohol consumption dataset.

# %%
df1.isna().sum()
# Out:
# Year              0
# WHO region        0
# Country           0
# Beverage Types    0
# Display Value     5
# dtype: int64

# %%
df1.isna().any()
# Out:
# Year              False
# WHO region        False
# Country           False
# Beverage Types    False
# Display Value      True
# dtype: bool

# %%
df1.dropna(how='any')
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# 4            Beer           1.98
# ..            ...            ...
# 95          Other           0.00
# 96           Wine           7.38
# 97           Wine           0.00
# 98           Wine           0.00
# 99           Wine           0.00
#
# [95 rows x 5 columns]

# %%
df1.dropna(how='any').isna().sum()
# Out:
# Year              0
# WHO region        0
# Country           0
# Beverage Types    0
# Display Value     0
# dtype: int64

# %% [markdown]
# 5. Write a Pandas program to remove the duplicates from 'WHO region' column of World alcohol consumption dataset.

# %%
df1.drop_duplicates('WHO region')
# Out:
#     Year             WHO region       Country Beverage Types  Display Value
# 0   1986        Western Pacific      Viet Nam           Wine           0.00
# 1   1986               Americas       Uruguay          Other           0.50
# 2   1985                 Africa  Cte d'Ivoire           Wine           1.62
# 13  1984  Eastern Mediterranean   Afghanistan          Other           0.00
# 18  1984                 Europe        Norway        Spirits           1.62
# 20  1986        South-East Asia       Myanmar           Wine           0.00

# %% [markdown]
# Write a Pandas program to find out the alcohol consumption of a given year from the world alcohol consumption dataset.

# %%
df1.loc[df1.Year == 1985, :]
# Out:
#     Year             WHO region  \
# 2   1985                 Africa
# 7   1985                 Africa
# 12  1985        Western Pacific
# 14  1985        Western Pacific
# 24  1985                 Africa
# 26  1985                 Europe
# 33  1985                 Africa
# 35  1985               Americas
# 44  1985                 Europe
# 50  1985                 Europe
# 63  1985  Eastern Mediterranean
# 71  1985                 Africa
# 76  1985                 Africa
# 77  1985                 Africa
# 80  1985                 Africa
# 81  1985                 Europe
# 85  1985                 Africa
# 94  1985                 Europe
# 96  1985                 Europe
# 99  1985        South-East Asia
#
#                                               Country Beverage Types  \
# 2                                        Cte d'Ivoire           Wine
# 7                                              Angola        Spirits
# 12                   Lao People's Democratic Republic           Beer
# 14                                           Viet Nam        Spirits
# 24                                            Comoros          Other
# 26  United Kingdom of Great Britain and Northern I...           Wine
# 33                                         Mauritania          Other
# 35                              Saint Kitts and Nevis        Spirits
# 44                                          Lithuania          Other
# 50                                        Switzerland          Other
# 63                                              Libya          Other
# 71                                               Mali          Other
# 76                                            Comoros           Beer
# 77                                           Cameroon        Spirits
# 80                                             Malawi          Other
# 81                                        Netherlands           Wine
# 85                   Democratic Republic of the Congo           Wine
# 94                                            Ukraine        Spirits
# 96                                         Luxembourg           Wine
# 99              Democratic People's Republic of Korea           Wine
#
#     Display Value
# 2            1.62
# 7            0.39
# 12           0.00
# 14           0.05
# 24            NaN
# 26           1.36
# 33           0.00
# 35           2.24
# 44            NaN
# 50           0.30
# 63           0.00
# 71           0.57
# 76           0.02
# 77           0.01
# 80           0.84
# 81           2.54
# 85           0.01
# 94           3.06
# 96           7.38
# 99           0.00

# %% [markdown]
# 7. Write a Pandas program to find out the alcohol consumption details in the year '1987' or '1989' from the world alcohol consumption dataset.

# %%
filter = (df1['Year'] == 1987) | (df1['Year'] == 1989)
df1.loc[filter, :]
# Out:
#     Year             WHO region                           Country  \
# 4   1987               Americas             Saint Kitts and Nevis
# 5   1987               Americas                         Guatemala
# 6   1987                 Africa                         Mauritius
# 10  1987                 Africa                          Botswana
# 11  1989               Americas                         Guatemala
# 15  1987                 Africa                     Guinea-Bissau
# 17  1989                 Africa                        Seychelles
# 21  1989               Americas                        Costa Rica
# 28  1987        Western Pacific                          Viet Nam
# 32  1989                 Africa                         Mauritius
# 36  1987  Eastern Mediterranean                             Egypt
# 38  1987  Eastern Mediterranean                             Qatar
# 39  1987                 Africa                      Burkina Faso
# 40  1987                 Europe                           Austria
# 45  1989                 Africa                          Zimbabwe
# 46  1987               Americas               Trinidad and Tobago
# 48  1987               Americas                         Nicaragua
# 51  1987                 Europe                           Finland
# 55  1989               Americas                          Suriname
# 56  1987        Western Pacific                          Viet Nam
# 57  1989                 Europe                           Croatia
# 59  1989  Eastern Mediterranean              Syrian Arab Republic
# 60  1987  Eastern Mediterranean        Iran (Islamic Republic of)
# 62  1987               Americas                          Suriname
# 64  1989               Americas  Bolivia (Plurinational State of)
# 65  1989  Eastern Mediterranean                           Somalia
# 66  1987  Eastern Mediterranean                              Iraq
# 67  1989                 Africa                           Namibia
# 68  1989                 Africa                            Uganda
# 72  1987                 Africa                        Mauritania
# 75  1989  Eastern Mediterranean                       Afghanistan
# 78  1989               Americas                           Jamaica
# 79  1989                 Europe                           Finland
# 82  1987                 Europe                           Ireland
# 87  1989  Eastern Mediterranean                              Iraq
# 88  1987  Eastern Mediterranean                           Lebanon
# 90  1989                 Africa                            Malawi
# 91  1989                 Europe                          Bulgaria
# 93  1987                 Africa                        Madagascar
#
#    Beverage Types  Display Value
# 4            Beer           1.98
# 5           Other           0.00
# 6            Wine           0.13
# 10           Wine           0.20
# 11           Beer           0.62
# 15           Wine           0.07
# 17           Beer           2.23
# 21        Spirits           4.51
# 28           Beer           0.11
# 32           Beer           1.60
# 36           Beer           0.07
# 38          Other           0.00
# 39        Spirits           0.01
# 40        Spirits           1.90
# 45           Beer           0.19
# 46        Spirits           2.26
# 48           Beer           0.70
# 51           Beer           3.88
# 55           Wine           0.04
# 56           Wine           0.00
# 57           Wine           5.10
# 59          Other           0.00
# 60          Other           0.00
# 62          Other           0.00
# 64           Beer           1.26
# 65           Beer           0.00
# 66           Wine           0.01
# 67           Beer           0.00
# 68           Beer           0.12
# 72          Other           0.00
# 75          Other           0.00
# 78          Other           0.00
# 79          Other           2.09
# 82        Spirits           2.25
# 87           Wine           0.01
# 88           Beer           0.42
# 90           Wine           0.01
# 91           Beer           4.43
# 93          Other            NaN

# %% [markdown]
# 8. Write a Pandas program to find out the alcohol consumption details by the 'Americas' in the year '1985' from the world alcohol consumption dataset.

# %%
df1[(df1['Year'] == 1985) & (df1['WHO region'] == 'Americas')]
# Out:
#     Year WHO region                Country Beverage Types  Display Value
# 35  1985   Americas  Saint Kitts and Nevis        Spirits           2.24

# %% [markdown]
# 9. Write a Pandas program to find out the alcohol consumption details in the year '1986' where WHO region is 'Western Pacific' and country is 'VietNam' from the world alcohol consumption dataset.

# %%
filter = (df1['WHO region'] == 'Western Pacific') & (df1['Country'] == 'Viet Nam')
#soln1
print(df1.loc[filter].head())


#soln2
df1[filter].head()
# Out:
#     Year       WHO region   Country Beverage Types  Display Value
# 0   1986  Western Pacific  Viet Nam           Wine           0.00
# 14  1985  Western Pacific  Viet Nam        Spirits           0.05
# 28  1987  Western Pacific  Viet Nam           Beer           0.11
# 56  1987  Western Pacific  Viet Nam           Wine           0.00
#     Year       WHO region   Country Beverage Types  Display Value
# 0   1986  Western Pacific  Viet Nam           Wine           0.00
# 14  1985  Western Pacific  Viet Nam        Spirits           0.05
# 28  1987  Western Pacific  Viet Nam           Beer           0.11
# 56  1987  Western Pacific  Viet Nam           Wine           0.00

# %% [markdown]
# 10. Write a Pandas program to find out the alcohol consumption details in the year '1986' or '1989' where WHO region is 'Americas' from the world alcohol consumption dataset.

# %%
df1[((df1['Year'] == 1985) | (df1['Year'] == 1989)) & ((df1['WHO region'] == 'Americas') | (df1['WHO region'] == 'Europe'))]
# Out:
#     Year WHO region                                            Country  \
# 11  1989   Americas                                          Guatemala
# 21  1989   Americas                                         Costa Rica
# 26  1985     Europe  United Kingdom of Great Britain and Northern I...
# 35  1985   Americas                              Saint Kitts and Nevis
# 44  1985     Europe                                          Lithuania
# 50  1985     Europe                                        Switzerland
# 55  1989   Americas                                           Suriname
# 57  1989     Europe                                            Croatia
# 64  1989   Americas                   Bolivia (Plurinational State of)
# 78  1989   Americas                                            Jamaica
# 79  1989     Europe                                            Finland
# 81  1985     Europe                                        Netherlands
# 91  1989     Europe                                           Bulgaria
# 94  1985     Europe                                            Ukraine
# 96  1985     Europe                                         Luxembourg
#
#    Beverage Types  Display Value
# 11           Beer           0.62
# 21        Spirits           4.51
# 26           Wine           1.36
# 35        Spirits           2.24
# 44          Other            NaN
# 50          Other           0.30
# 55           Wine           0.04
# 57           Wine           5.10
# 64           Beer           1.26
# 78          Other           0.00
# 79          Other           2.09
# 81           Wine           2.54
# 91           Beer           4.43
# 94        Spirits           3.06
# 96           Wine           7.38

# %% [markdown]
# 11. Write a Pandas program to find out the alcohol consumption details in the year '1986' or '1989' where WHO region is 'Americas' or 'Europe' from the world alcohol consumption dataset.

# %%
year = (df1['Year'] == 1986) | (df1['Year'] == 1989)
place = (df1['WHO region'] == 'Americas') | (df1['WHO region'] == 'Europe')
df1.loc[(year & place), 'WHO region': 'Beverage Types']
# Out:
#    WHO region                           Country Beverage Types
# 1    Americas                           Uruguay          Other
# 3    Americas                          Colombia           Beer
# 8    Americas               Antigua and Barbuda        Spirits
# 11   Americas                         Guatemala           Beer
# 21   Americas                        Costa Rica        Spirits
# 29     Europe                             Italy          Other
# 34     Europe                Russian Federation           Wine
# 37     Europe                            Sweden           Beer
# 41     Europe                    Czech Republic           Beer
# 47   Americas                            Mexico          Other
# 49     Europe                             Malta           Wine
# 55   Americas                          Suriname           Wine
# 57     Europe                           Croatia           Wine
# 64   Americas  Bolivia (Plurinational State of)           Beer
# 74   Americas  Bolivia (Plurinational State of)        Spirits
# 78   Americas                           Jamaica          Other
# 79     Europe                           Finland          Other
# 83     Europe                           Ukraine          Other
# 86   Americas                           Bahamas           Wine
# 91     Europe                          Bulgaria           Beer

# %%
(year & place).values
df1.iloc[(year & place).values, 1:3]
# Out:
#    WHO region                           Country
# 1    Americas                           Uruguay
# 3    Americas                          Colombia
# 8    Americas               Antigua and Barbuda
# 11   Americas                         Guatemala
# 21   Americas                        Costa Rica
# 29     Europe                             Italy
# 34     Europe                Russian Federation
# 37     Europe                            Sweden
# 41     Europe                    Czech Republic
# 47   Americas                            Mexico
# 49     Europe                             Malta
# 55   Americas                          Suriname
# 57     Europe                           Croatia
# 64   Americas  Bolivia (Plurinational State of)
# 74   Americas  Bolivia (Plurinational State of)
# 78   Americas                           Jamaica
# 79     Europe                           Finland
# 83     Europe                           Ukraine
# 86   Americas                           Bahamas
# 91     Europe                          Bulgaria

# %% [markdown]
# 13. Write a Pandas program to find out the records where consumption of beverages per person average >=5 and Beverage Types is Beer from world alcohol consumption dataset.

# %%
mask = (df1['Display Value'] >= 5) & (df1['Beverage Types'] == 'Beer')
df1[mask]
# Out:
#     Year WHO region         Country Beverage Types  Display Value
# 41  1986     Europe  Czech Republic           Beer           6.82

# %% [markdown]
# 14. Write a Pandas program to find out the records where consumption of beverages per person average >=4 and Beverage Types is Beer, Wine, Spirits from world alcohol consumption dataset.

# %%
mask = (df1['Display Value'] >= 4) & (df1['Beverage Types'] == 'Beer')
df1[mask]
# Out:
#     Year WHO region         Country Beverage Types  Display Value
# 3   1986   Americas        Colombia           Beer           4.27
# 41  1986     Europe  Czech Republic           Beer           6.82
# 91  1989     Europe        Bulgaria           Beer           4.43

# %% [markdown]
# 15. Write a Pandas program to filter the specified columns and records by range from world alcohol consumption dataset.

# %%
df1.iloc[:5, 1:6]
# Out:
#         WHO region                Country Beverage Types  Display Value
# 0  Western Pacific               Viet Nam           Wine           0.00
# 1         Americas                Uruguay          Other           0.50
# 2           Africa           Cte d'Ivoire           Wine           1.62
# 3         Americas               Colombia           Beer           4.27
# 4         Americas  Saint Kitts and Nevis           Beer           1.98

# %% [markdown]
# 16. Write a Pandas program to filter those records where WHO region contains "Ea" substring from world alcohol consumption dataset.

# %%
mask = df1['WHO region'].str.contains("Ea")
df1[mask]
# Out:
#     Year             WHO region                                Country  \
# 13  1984  Eastern Mediterranean                            Afghanistan
# 20  1986        South-East Asia                                Myanmar
# 25  1984  Eastern Mediterranean                                Tunisia
# 27  1984  Eastern Mediterranean                                Bahrain
# 36  1987  Eastern Mediterranean                                  Egypt
# 38  1987  Eastern Mediterranean                                  Qatar
# 52  1986  Eastern Mediterranean                           Saudi Arabia
# 53  1984  Eastern Mediterranean                                 Kuwait
# 58  1984  Eastern Mediterranean                                Somalia
# 59  1989  Eastern Mediterranean                   Syrian Arab Republic
# 60  1987  Eastern Mediterranean             Iran (Islamic Republic of)
# 63  1985  Eastern Mediterranean                                  Libya
# 65  1989  Eastern Mediterranean                                Somalia
# 66  1987  Eastern Mediterranean                                   Iraq
# 73  1986  Eastern Mediterranean                               Pakistan
# 75  1989  Eastern Mediterranean                            Afghanistan
# 84  1986        South-East Asia                              Sri Lanka
# 87  1989  Eastern Mediterranean                                   Iraq
# 88  1987  Eastern Mediterranean                                Lebanon
# 89  1986  Eastern Mediterranean                                Lebanon
# 97  1984        South-East Asia                              Indonesia
# 99  1985        South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 13          Other           0.00
# 20           Wine           0.00
# 25          Other           0.00
# 27           Beer           2.22
# 36           Beer           0.07
# 38          Other           0.00
# 52           Wine           0.00
# 53           Beer           0.00
# 58        Spirits           0.00
# 59          Other           0.00
# 60          Other           0.00
# 63          Other           0.00
# 65           Beer           0.00
# 66           Wine           0.01
# 73          Other           0.01
# 75          Other           0.00
# 84          Other           0.00
# 87           Wine           0.01
# 88           Beer           0.42
# 89           Wine           0.70
# 97           Wine           0.00
# 99           Wine           0.00

# %% [markdown]
# 17. Write a Pandas program to filter those records where WHO region matches with multiple values (Africa, Eastern Mediterranean, Europe) from world alcohol consumption dataset.

# %%
mask = df1['WHO region'].isin(['Africa', 'Eastern Mediterranean', 'Europe'])

# %%
df1[mask].sample(5)
# Out:
#     Year             WHO region            Country Beverage Types  \
# 65  1989  Eastern Mediterranean            Somalia           Beer
# 42  1984                 Europe            Ukraine        Spirits
# 17  1989                 Africa         Seychelles           Beer
# 41  1986                 Europe     Czech Republic           Beer
# 98  1984                 Africa  Equatorial Guinea           Wine
#
#     Display Value
# 65           0.00
# 42           3.06
# 17           2.23
# 41           6.82
# 98           0.00

# %% [markdown]
# 18. Write a Pandas program to filter those records which not appears in a given list from world alcohol consumption dataset.

# %%
mask = ~df1['WHO region'].isin(['Africa', 'Eastern Mediterranean', 'Europe'])

# %%
df1[mask]
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# 5   1987         Americas                              Guatemala
# 8   1986         Americas                    Antigua and Barbuda
# 11  1989         Americas                              Guatemala
# 12  1985  Western Pacific       Lao People's Democratic Republic
# 14  1985  Western Pacific                               Viet Nam
# 16  1984         Americas                             Costa Rica
# 20  1986  South-East Asia                                Myanmar
# 21  1989         Americas                             Costa Rica
# 28  1987  Western Pacific                               Viet Nam
# 31  1986  Western Pacific       Micronesia (Federated States of)
# 35  1985         Americas                  Saint Kitts and Nevis
# 43  1984  Western Pacific                                  China
# 46  1987         Americas                    Trinidad and Tobago
# 47  1986         Americas                                 Mexico
# 48  1987         Americas                              Nicaragua
# 54  1984         Americas                            El Salvador
# 55  1989         Americas                               Suriname
# 56  1987  Western Pacific                               Viet Nam
# 61  1984  Western Pacific                       Papua New Guinea
# 62  1987         Americas                               Suriname
# 64  1989         Americas       Bolivia (Plurinational State of)
# 74  1986         Americas       Bolivia (Plurinational State of)
# 78  1989         Americas                                Jamaica
# 84  1986  South-East Asia                              Sri Lanka
# 86  1986         Americas                                Bahamas
# 97  1984  South-East Asia                              Indonesia
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 3            Beer           4.27
# 4            Beer           1.98
# 5           Other           0.00
# 8         Spirits           1.55
# 11           Beer           0.62
# 12           Beer           0.00
# 14        Spirits           0.05
# 16           Wine           0.06
# 20           Wine           0.00
# 21        Spirits           4.51
# 28           Beer           0.11
# 31           Wine           0.00
# 35        Spirits           2.24
# 43           Wine           0.03
# 46        Spirits           2.26
# 47          Other           0.04
# 48           Beer           0.70
# 54        Spirits           1.81
# 55           Wine           0.04
# 56           Wine           0.00
# 61        Spirits           0.08
# 62          Other           0.00
# 64           Beer           1.26
# 74        Spirits           2.06
# 78          Other           0.00
# 84          Other           0.00
# 86           Wine           1.83
# 97           Wine           0.00
# 99           Wine           0.00

# %% [markdown]
# 19. Write a Pandas program to filter all records where the average consumption of beverages per person from .5 to 2.50 in world alcohol consumption dataset.

# %%
df1[df1['Display Value'].between(0.5, 2.5)]
# Out:
#     Year             WHO region  \
# 1   1986               Americas
# 2   1985                 Africa
# 4   1987               Americas
# 8   1986               Americas
# 11  1989               Americas
# 17  1989                 Africa
# 18  1984                 Europe
# 19  1984                 Africa
# 26  1985                 Europe
# 27  1984  Eastern Mediterranean
# 32  1989                 Africa
# 34  1986                 Europe
# 35  1985               Americas
# 40  1987                 Europe
# 46  1987               Americas
# 48  1987               Americas
# 49  1986                 Europe
# 54  1984               Americas
# 64  1989               Americas
# 70  1986                 Africa
# 71  1985                 Africa
# 74  1986               Americas
# 79  1989                 Europe
# 80  1985                 Africa
# 82  1987                 Europe
# 86  1986               Americas
# 89  1986  Eastern Mediterranean
#
#                                               Country Beverage Types  \
# 1                                             Uruguay          Other
# 2                                        Cte d'Ivoire           Wine
# 4                               Saint Kitts and Nevis           Beer
# 8                                 Antigua and Barbuda        Spirits
# 11                                          Guatemala           Beer
# 17                                         Seychelles           Beer
# 18                                             Norway        Spirits
# 19                                              Kenya           Beer
# 26  United Kingdom of Great Britain and Northern I...           Wine
# 27                                            Bahrain           Beer
# 32                                          Mauritius           Beer
# 34                                 Russian Federation           Wine
# 35                              Saint Kitts and Nevis        Spirits
# 40                                            Austria        Spirits
# 46                                Trinidad and Tobago        Spirits
# 48                                          Nicaragua           Beer
# 49                                              Malta           Wine
# 54                                        El Salvador        Spirits
# 64                   Bolivia (Plurinational State of)           Beer
# 70                                         Madagascar        Spirits
# 71                                               Mali          Other
# 74                   Bolivia (Plurinational State of)        Spirits
# 79                                            Finland          Other
# 80                                             Malawi          Other
# 82                                            Ireland        Spirits
# 86                                            Bahamas           Wine
# 89                                            Lebanon           Wine
#
#     Display Value
# 1            0.50
# 2            1.62
# 4            1.98
# 8            1.55
# 11           0.62
# 17           2.23
# 18           1.62
# 19           1.08
# 26           1.36
# 27           2.22
# 32           1.60
# 34           0.80
# 35           2.24
# 40           1.90
# 46           2.26
# 48           0.70
# 49           1.49
# 54           1.81
# 64           1.26
# 70           1.02
# 71           0.57
# 74           2.06
# 79           2.09
# 80           0.84
# 82           2.25
# 86           1.83
# 89           0.70

# %% [markdown]
# 20. Write a Pandas program to find average consumption of wine per person greater than 2 in world alcohol consumption dataset.

# %%
df1[df1['Display Value'] > 2]
# Out:
#     Year             WHO region                           Country  \
# 3   1986               Americas                          Colombia
# 9   1984                 Africa                           Nigeria
# 17  1989                 Africa                        Seychelles
# 21  1989               Americas                        Costa Rica
# 22  1984                 Europe                           Romania
# 27  1984  Eastern Mediterranean                           Bahrain
# 30  1986                 Africa                      Sierra Leone
# 35  1985               Americas             Saint Kitts and Nevis
# 37  1986                 Europe                            Sweden
# 41  1986                 Europe                    Czech Republic
# 42  1984                 Europe                           Ukraine
# 46  1987               Americas               Trinidad and Tobago
# 51  1987                 Europe                           Finland
# 57  1989                 Europe                           Croatia
# 74  1986               Americas  Bolivia (Plurinational State of)
# 79  1989                 Europe                           Finland
# 81  1985                 Europe                       Netherlands
# 82  1987                 Europe                           Ireland
# 91  1989                 Europe                          Bulgaria
# 94  1985                 Europe                           Ukraine
# 96  1985                 Europe                        Luxembourg
#
#    Beverage Types  Display Value
# 3            Beer           4.27
# 9           Other           6.10
# 17           Beer           2.23
# 21        Spirits           4.51
# 22        Spirits           2.67
# 27           Beer           2.22
# 30          Other           4.48
# 35        Spirits           2.24
# 37           Beer           3.04
# 41           Beer           6.82
# 42        Spirits           3.06
# 46        Spirits           2.26
# 51           Beer           3.88
# 57           Wine           5.10
# 74        Spirits           2.06
# 79          Other           2.09
# 81           Wine           2.54
# 82        Spirits           2.25
# 91           Beer           4.43
# 94        Spirits           3.06
# 96           Wine           7.38

# %% [markdown]
# 21. Write a Pandas program to filter rows based on row numbers ended with 0, like 0, 10, 20, 30 from world alcohol consumption dataset

# %%
df1.index%10 == 0
df1[df1.index%10 == 0]
# Out:
#     Year             WHO region                     Country Beverage Types  \
# 0   1986        Western Pacific                    Viet Nam           Wine
# 10  1987                 Africa                    Botswana           Wine
# 20  1986        South-East Asia                     Myanmar           Wine
# 30  1986                 Africa                Sierra Leone          Other
# 40  1987                 Europe                     Austria        Spirits
# 50  1985                 Europe                 Switzerland          Other
# 60  1987  Eastern Mediterranean  Iran (Islamic Republic of)          Other
# 70  1986                 Africa                  Madagascar        Spirits
# 80  1985                 Africa                      Malawi          Other
# 90  1989                 Africa                      Malawi           Wine
#
#     Display Value
# 0            0.00
# 10           0.20
# 20           0.00
# 30           4.48
# 40           1.90
# 50           0.30
# 60           0.00
# 70           1.02
# 80           0.84
# 90           0.01

# %%
df1.filter(regex='0$', axis=0)
# Out:
#     Year             WHO region                     Country Beverage Types  \
# 0   1986        Western Pacific                    Viet Nam           Wine
# 10  1987                 Africa                    Botswana           Wine
# 20  1986        South-East Asia                     Myanmar           Wine
# 30  1986                 Africa                Sierra Leone          Other
# 40  1987                 Europe                     Austria        Spirits
# 50  1985                 Europe                 Switzerland          Other
# 60  1987  Eastern Mediterranean  Iran (Islamic Republic of)          Other
# 70  1986                 Africa                  Madagascar        Spirits
# 80  1985                 Africa                      Malawi          Other
# 90  1989                 Africa                      Malawi           Wine
#
#     Display Value
# 0            0.00
# 10           0.20
# 20           0.00
# 30           4.48
# 40           1.90
# 50           0.30
# 60           0.00
# 70           1.02
# 80           0.84
# 90           0.01

# %% [markdown]
# Write a Pandas program to select consecutive columns and also select rows with Index label 0 to 9 with some columns from world alcohol consumption

# %%
df1.iloc[0:10, 0:4]
# Out:
#    Year       WHO region                Country Beverage Types
# 0  1986  Western Pacific               Viet Nam           Wine
# 1  1986         Americas                Uruguay          Other
# 2  1985           Africa           Cte d'Ivoire           Wine
# 3  1986         Americas               Colombia           Beer
# 4  1987         Americas  Saint Kitts and Nevis           Beer
# 5  1987         Americas              Guatemala          Other
# 6  1987           Africa              Mauritius           Wine
# 7  1985           Africa                 Angola        Spirits
# 8  1986         Americas    Antigua and Barbuda        Spirits
# 9  1984           Africa                Nigeria          Other

# %% [markdown]
# 23. Write a Pandas program to rename all and only some of the column names from world alcohol consumption dataset.

# %%
# rename all the column names
df1.columns.str.lower()
# Out:
# Index(['year', 'who region', 'country', 'beverage types', 'display value'], dtype='object')

# %%
# renameall soln2
# df1.columns = ['year', 'whoregion', 'countries', 'beverage__types', 'display_value']

# %%
#rename some columns
# df1.rename(columns={'Year': 'year', 'WHO region': 'who_region'})

# %%
# df1.columns = pd.Series(('year','who_region','country','beverage_types','display_values'))

# %% [markdown]
# 24. Write a Pandas program to find which years have all non-zero values and which years have any non-zero values from world alcohol consumption dataset.

# %%
#printing only those rows with any null values
msk = df1.isna().any(axis=1)
df1[msk]
# Out:
#     Year WHO region     Country Beverage Types  Display Value
# 24  1985     Africa     Comoros          Other            NaN
# 29  1986     Europe       Italy          Other            NaN
# 44  1985     Europe   Lithuania          Other            NaN
# 83  1986     Europe     Ukraine          Other            NaN
# 93  1987     Africa  Madagascar          Other            NaN

# %%
#rows with all null values
df1.isnull().all(axis=1)
df1[df1.isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Year, WHO region, Country, Beverage Types, Display Value]
# Index: []

# %%
#years with any non-zero values
f = df1.notna().any(axis=1)
print(df1[f].shape)
print(f"df1 shape: {df1.shape}")
print(df1[f])
# Out:
# (100, 5)
# df1 shape: (100, 5)
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# 4            Beer           1.98
# ..            ...            ...
# 95          Other           0.00
# 96           Wine           7.38
# 97           Wine           0.00
# 98           Wine           0.00
# 99           Wine           0.00
#
# [100 rows x 5 columns]

# %%
#years with all non-zero values
f = df1.notna().all(axis=1)
print(df1[f].head())
print(df1[f].isna().sum())
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
# Year              0
# WHO region        0
# Country           0
# Beverage Types    0
# Display Value     0
# dtype: int64

# %% [markdown]
# 25. Write a Pandas program to filter all columns where all entries present, check which rows and columns has a NaN and finally drop rows with any NaNs from world alcohol consumption dataset.

# %%
# columns with all entries present
df1.loc[:, df1.notna().all()]
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types
# 0            Wine
# 1           Other
# 2            Wine
# 3            Beer
# 4            Beer
# ..            ...
# 95          Other
# 96           Wine
# 97           Wine
# 98           Wine
# 99           Wine
#
# [100 rows x 4 columns]

# %%
# which rows has NAN has already been checked above in Q24

#which  columns has NAN
df1.loc[:, df1.isnull().any()]
# Out:
#     Display Value
# 0            0.00
# 1            0.50
# 2            1.62
# 3            4.27
# 4            1.98
# ..            ...
# 95           0.00
# 96           7.38
# 97           0.00
# 98           0.00
# 99           0.00
#
# [100 rows x 1 columns]

# %%
## drop rowsx with nan
# new df with rows containing nan values dropped.
df1.dropna(axis=0)
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# 4            Beer           1.98
# ..            ...            ...
# 95          Other           0.00
# 96           Wine           7.38
# 97           Wine           0.00
# 98           Wine           0.00
# 99           Wine           0.00
#
# [95 rows x 5 columns]

# %%
df1.all(axis=0, skipna=False)
# Out:
# Year               True
# WHO region         True
# Country            True
# Beverage Types     True
# Display Value     False
# dtype: bool

# %%
df1[df1.all(axis=1)]
# Out:
#     Year WHO region                Country Beverage Types  Display Value
# 1   1986   Americas                Uruguay          Other           0.50
# 2   1985     Africa           Cte d'Ivoire           Wine           1.62
# 3   1986   Americas               Colombia           Beer           4.27
# 4   1987   Americas  Saint Kitts and Nevis           Beer           1.98
# 6   1987     Africa              Mauritius           Wine           0.13
# ..   ...        ...                    ...            ...            ...
# 90  1989     Africa                 Malawi           Wine           0.01
# 91  1989     Europe               Bulgaria           Beer           4.43
# 93  1987     Africa             Madagascar          Other            NaN
# 94  1985     Europe                Ukraine        Spirits           3.06
# 96  1985     Europe             Luxembourg           Wine           7.38
#
# [72 rows x 5 columns]

# %%
df1['Year'].all()
# Out:
# True

# %%
(df1.loc[:,df1.all(skipna=False)])
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types
# 0            Wine
# 1           Other
# 2            Wine
# 3            Beer
# 4            Beer
# ..            ...
# 95          Other
# 96           Wine
# 97           Wine
# 98           Wine
# 99           Wine
#
# [100 rows x 4 columns]

# %%
 # any non zero values
df1[df1.any(axis=1)]
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# 4            Beer           1.98
# ..            ...            ...
# 95          Other           0.00
# 96           Wine           7.38
# 97           Wine           0.00
# 98           Wine           0.00
# 99           Wine           0.00
#
# [100 rows x 5 columns]

# %%
df1.loc[:, df1.all()].isna().sum()
# Out:
# Year              0
# WHO region        0
# Country           0
# Beverage Types    0
# dtype: int64

# %%
df1.loc[:, df1.notna().all()]
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types
# 0            Wine
# 1           Other
# 2            Wine
# 3            Beer
# 4            Beer
# ..            ...
# 95          Other
# 96           Wine
# 97           Wine
# 98           Wine
# 99           Wine
#
# [100 rows x 4 columns]

# %%
df1.loc[:, df1.isna().any()]
# Out:
#     Display Value
# 0            0.00
# 1            0.50
# 2            1.62
# 3            4.27
# 4            1.98
# ..            ...
# 95           0.00
# 96           7.38
# 97           0.00
# 98           0.00
# 99           0.00
#
# [100 rows x 1 columns]

# %%
df1.loc[:, 'WHO region':]
# Out:
#          WHO region                                Country Beverage Types  \
# 0   Western Pacific                               Viet Nam           Wine
# 1          Americas                                Uruguay          Other
# 2            Africa                           Cte d'Ivoire           Wine
# 3          Americas                               Colombia           Beer
# 4          Americas                  Saint Kitts and Nevis           Beer
# ..              ...                                    ...            ...
# 95           Africa                                  Niger          Other
# 96           Europe                             Luxembourg           Wine
# 97  South-East Asia                              Indonesia           Wine
# 98           Africa                      Equatorial Guinea           Wine
# 99  South-East Asia  Democratic People's Republic of Korea           Wine
#
#     Display Value
# 0            0.00
# 1            0.50
# 2            1.62
# 3            4.27
# 4            1.98
# ..            ...
# 95           0.00
# 96           7.38
# 97           0.00
# 98           0.00
# 99           0.00
#
# [100 rows x 4 columns]

# %% [markdown]
# 26. Write a Pandas program to filter all records starting from the 'Year' column, access every other column from world alcohol consumption dataset.

# %%
df1.loc[:, 'Year'::2]
# Out:
#     Year                                Country  Display Value
# 0   1986                               Viet Nam           0.00
# 1   1986                                Uruguay           0.50
# 2   1985                           Cte d'Ivoire           1.62
# 3   1986                               Colombia           4.27
# 4   1987                  Saint Kitts and Nevis           1.98
# ..   ...                                    ...            ...
# 95  1984                                  Niger           0.00
# 96  1985                             Luxembourg           7.38
# 97  1984                              Indonesia           0.00
# 98  1984                      Equatorial Guinea           0.00
# 99  1985  Democratic People's Republic of Korea           0.00
#
# [100 rows x 3 columns]

# %% [markdown]
# 27. Write a Pandas program to filter all records starting from the 2nd row, access every 5th row from world alcohol consumption dataset.

# %%
df1.loc[1::5, :]
# Out:
#     Year             WHO region  \
# 1   1986               Americas
# 6   1987                 Africa
# 11  1989               Americas
# 16  1984               Americas
# 21  1989               Americas
# 26  1985                 Europe
# 31  1986        Western Pacific
# 36  1987  Eastern Mediterranean
# 41  1986                 Europe
# 46  1987               Americas
# 51  1987                 Europe
# 56  1987        Western Pacific
# 61  1984        Western Pacific
# 66  1987  Eastern Mediterranean
# 71  1985                 Africa
# 76  1985                 Africa
# 81  1985                 Europe
# 86  1986               Americas
# 91  1989                 Europe
# 96  1985                 Europe
#
#                                               Country Beverage Types  \
# 1                                             Uruguay          Other
# 6                                           Mauritius           Wine
# 11                                          Guatemala           Beer
# 16                                         Costa Rica           Wine
# 21                                         Costa Rica        Spirits
# 26  United Kingdom of Great Britain and Northern I...           Wine
# 31                   Micronesia (Federated States of)           Wine
# 36                                              Egypt           Beer
# 41                                     Czech Republic           Beer
# 46                                Trinidad and Tobago        Spirits
# 51                                            Finland           Beer
# 56                                           Viet Nam           Wine
# 61                                   Papua New Guinea        Spirits
# 66                                               Iraq           Wine
# 71                                               Mali          Other
# 76                                            Comoros           Beer
# 81                                        Netherlands           Wine
# 86                                            Bahamas           Wine
# 91                                           Bulgaria           Beer
# 96                                         Luxembourg           Wine
#
#     Display Value
# 1            0.50
# 6            0.13
# 11           0.62
# 16           0.06
# 21           4.51
# 26           1.36
# 31           0.00
# 36           0.07
# 41           6.82
# 46           2.26
# 51           3.88
# 56           0.00
# 61           0.08
# 66           0.01
# 71           0.57
# 76           0.02
# 81           2.54
# 86           1.83
# 91           4.43
# 96           7.38
